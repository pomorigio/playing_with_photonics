# %%
import gdsfactory as gf
import matplotlib.pyplot as plt
import meep as mp
import numpy as np
from gdsfactory.generic_tech import get_generic_pdk
from meep import MaterialGrid, Medium, Vector3, Volume
from meep.adjoint import (
    DesignRegion,
    get_conic_radius_from_eta_e,
)

import gplugins
import gplugins.gmeep as gm
from gplugins.gmeep.get_simulation import get_simulation

gf.config.rich_output()
PDK = get_generic_pdk()
PDK.activate()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from gdsfactory.generic_tech import get_generic_pdk
#       6 from meep import MaterialGrid, Medium, Vector3, Volume
# ----> 7 from meep.adjoint import (
#       8     DesignRegion,
#       9     get_conic_radius_from_eta_e,
#      10 )
#      12 import gplugins
#      13 import gplugins.gmeep as gm
#
# File ~/miniconda/envs/photonics/lib/python3.13/site-packages/meep/adjoint/__init__.py:13
#       9 from .utils import DesignRegion
#      11 from .basis import BilinearInterpolationBasis
# ---> 13 from .optimization_problem import OptimizationProblem
#      15 from .filter_source import FilteredSource
#      17 from .filters import *
#
# File ~/miniconda/envs/photonics/lib/python3.13/site-packages/meep/adjoint/optimization_problem.py:5
#       2 from typing import Callable, List, Union, Optional, Tuple
#       4 import numpy as np
# ----> 5 from autograd import grad, jacobian
#       7 import meep as mp
#       9 from . import LDOS, DesignRegion, utils, ObjectiveQuantity
#
# ModuleNotFoundError: No module named 'autograd'
