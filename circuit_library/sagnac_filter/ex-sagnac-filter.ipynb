# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from circuit_library.sagnac_filter.cell import sagnac_filter
from axiomatic.pic_helpers import plot_circuit

# Example usage
if __name__ == "__main__":
    c = sagnac_filter(
        coupling_length=10.0,  # µm
        target_fsr=1.0,      # nm
        coupling_gap=0.2,
        center_wavelength=1.55,
        n_g=4.3,
        n_eff=2.38,
        bend_radius=50.0
    )
    plot_circuit(c)
# Out:
# Computed loop length: 518.3289302325582 µm
