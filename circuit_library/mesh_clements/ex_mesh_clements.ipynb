# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from circuit_library.mesh_clements.cell import clements_NxN
from axiomatic.pic_helpers import plot_circuit

# Example usage.
if __name__ == "__main__":
    c = clements_NxN(n_ports=6)
    plot_circuit(c)
