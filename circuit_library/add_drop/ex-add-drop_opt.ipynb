# %%
import gdsfactory as gf
import numpy as np
import cspdk.si220.cband
from axiomatic.pic_helpers import plot_circuit
cspdk.si220.cband.activate_pdk()

pdk = gf.get_active_pdk()
c = gf.Component()

def add_drop(coupling_length: float, target_fsr: float, center_wvl: float) -> gf.Component:
    bend_radius = 5  # Bend radius in micrometers
    n_eff = 2.38
    n_g = 4.3

    cavity_length_target_fsr = center_wvl**2 / (n_g * target_fsr * 1e-3)

    m = round(n_eff * cavity_length_target_fsr / center_wvl)
    ring_length_target = m * center_wvl / n_eff  # Actual round-trip length for resonance at 1.55 um
    length_arc = 2 * np.pi * bend_radius

    c = gf.Component()
    coupler = lambda L: pdk.get_component("coupler", length=L, gap=coupling_gap)

    # Place couplers
    for i, L in enumerate(coupling_lengths):
        dc = c << coupler(L)
        dc.move((i * stage_spacing, 0))
        couplers.append(dc)

    # Add ports
    c.add_port("in0", port=ring.ports["o1"])
    c.add_port("out0", port=ring.ports["o2"])

    return c


# Example usage and plot
if __name__ == "__main__":
    c = ring_resonator(
        coupling_length = 0.2, 
        target_fsr = 1, 
        center_wvl = 1.55)
    plot_circuit(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 39
#      37 # Example usage and plot
#      38 if __name__ == "__main__":
# ---> 39     c = ring_resonator(
#      40         coupling_length = 0.2,
#      41         target_fsr = 1,
#      42         center_wvl = 1.55)
#      43     plot_circuit(c)
#
# NameError: name 'ring_resonator' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# LockedError                               Traceback (most recent call last)
# Cell In[18], line 11
#       9 L = 10.4
#      10 coupler = pdk.get_component("coupler", length=L, gap=0.2)
# ---> 11 coupler_flat = coupler.flatten()
#      13 # Ports
#      14 port_pairs = [("o1", "o4"), ("o2", "o3")]
#
# File c:\Users\aitor\miniconda3\envs\ax-stack\Lib\site-packages\kfactory\kcell.py:1029, in ProtoTKCell.flatten(self, merge)
#    1023 """Flatten the cell.
#    1024
#    1025 Args:
#    1026     merge: Merge the shapes on all layers.
#    1027 """
#    1028 if self.locked:
# -> 1029     raise LockedError(self)
#    1030 for vinst in self._base.vinsts:
#    1031     vinst.insert_into_flat(self)
#
# LockedError: 'coupler_L10p4_G0p2' is locked and likely stored in cache. Modifications are disabled as its associated function is decorated with `cell`. To modify, update the code in the function or create a copy of the Component.
