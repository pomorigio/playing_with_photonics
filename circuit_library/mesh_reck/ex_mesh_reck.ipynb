# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from circuit_library.mesh_reck.cell import reck_NxN
from axiomatic.pic_helpers import plot_circuit

# Example usage
if __name__ == "__main__":
    c = reck_NxN(n_ports=4)
    plot_circuit(c)
